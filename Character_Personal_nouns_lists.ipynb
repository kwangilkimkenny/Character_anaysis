# %% [markdown]
# personal nouns관련 단어들을 모두 모아서 txt파일로 만든다. 이것을 리스트로 만들어서 입력된(Essay)문장과 비교한다.

# %%
import re
import nltk
from nltk.stem import PorterStemmer, LancasterStemmer #어간추출

# %%
#txt 파일을 불러온다.
text_input=[]

file=open("data/personal_nouns.txt", 'r')

while (1):
    line=file.readline()

    try:escape=line.index('\n')
    except:escape=len(line)
    
    if line:
        text_input.append(line[0:escape])
    else:
        break
    
file.close()

# %%
print(text_input[0:3])
# Out:
# ['\ufeffAcademician, Acceptor, Ace, Ace-in-the-hole, Achiever, Adept, Adherent, Administrator, Admirer, Adorer, Advantage, Adviser, Advisor, Advocate, Aelurophile, Aerophile, Aesthete, Aficionada/Aficionado, Aid, Aide, Ailurophile, Alannah, Alleviator, Ally, Almsgiver, Almsperson, Alternate, Altruist, Agent, (noun)-aholic [ex. workaholic, Ambassador, Amoret, Angel, Aficionada, Aficionado, Affluential, Americophile, Amerindophile/Amerindophilist, Anglophile, Apostle, Appreciator, Apprentice, Arctophile, Arbiter, Archetype, Architect, Artisan, Artist, Artiste, Ascendant, Aspirant, Asset, Assignee, Assigner, Assistant, Associate, Astrophile, Athlete, Attendant, Audiophile, Author, Authority, Autodidact, Awardee', "Baby, Backbone, Backer, Backup, Ball of fire, Baron, Beata, Beatus, Beaut, Beauty, Beau ideal, Bee's Knees, Begetter, Being, Bel-esprit, Believer, Belle, Benchmark, Benefactor, Benefactress, Beneficiary, Benefit, Bestower, Bibliophile, Big cheese, Big enchilada, Big fish, Big gun, Big wheel, Bigwig, Biophile, Blessing, Bodyguard, Bon vivant, Boss, Booster, Brain, Brass, Brother, Bud, Buddy, Buff, Bundle of energy, Bundle of joy, Builder", "Campaigner, Captain, Carer, Caretaker, Cartophile, Catalyst, Cat's meow, Cause, Cavalier, Celebrant, Celebrator, Center of attention, CEO, CFO, Chair, Chairperson, Chamberlain, Champ, Champion, Chaperon, Charmer, Cherub, Cherisher, Chief, Chieftan, Child, Chum, Cinephile, Clerisy, Climber, Coadjutant, Coadjutor, Cognoscente, Cognoscenti, Cohort, Coiner, Collaborator, Colleague, Collector, Comforter, Commander, Companion, Compeller, Complement, Composer, Comrade, Concert pianist, Concierge, Conductor, Confederate, Conferrer, Confidant, Confrere, Connoisseur, Conservator, Consoler, Consul, Consultant, Contributor, Controller, Convive,\xa0 Cooperator, Corker, Cornerstone, Cosmocrat, Cosmopolitan/Cosmopolite, Councillor, Counsel, Counselor, Counsellor, Count, Co-worker, Crackerjack, Craftsperson, Creator, Credit, Crew, Cub, Curator, Custodian, Cynosure"]

# %%
from nltk.corpus import stopwords

# %%
def preprocessing(text_nouns, remove_stopwords=False):
        
    # 영어가 아닌 특수문자들을 공백(" ")으로 바꾸기
    #processed_text = re.sub("[^a-zA-Z]", " ", text_nouns)
 
    #텍스트에 포함되어 있는 특수 문자 제거
 
    processed_text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', text_nouns)
 

    # 대문자들을 소문자로 바꾸고 공백단위로 텍스트들 나눠서 리스트로 만든다.
    words =  processed_text.lower().split()

    if remove_stopwords: 
        # 불용어들을 제거
    
        #영어에 관련된 불용어 불러오기
        stops = set(stopwords.words("english"))
        # 불용어가 아닌 단어들로 이루어진 새로운 리스트 생성
        words = [w for w in words if not w in stops]
        # 단어 리스트를 ,를 넣어서 하나의 글로 합친다.
        clean_nouns_texts= ' '.join(words)

    else: # 불용어 제거하지 않을 때
        clean_nouns_texts = ' '.join(words)

    return clean_nouns_texts

# %%
clean_data_ = []
for review in text_input:
    #list to str
    str_data = ' '.join(text_input)
    clean_data_.append(preprocessing(str_data, remove_stopwords=True))

# 전처리된 데이터 확인. 잘됨 !! ㅎ
clean_data_[0]
# Out:
# '\ufeffacademician acceptor ace aceinthehole achiever adept adherent administrator admirer adorer advantage adviser advisor advocate aelurophile aerophile aesthete aficionadaaficionado aid aide ailurophile alannah alleviator ally almsgiver almsperson alternate altruist agent nounaholic ex workaholic ambassador amoret angel aficionada aficionado affluential americophile amerindophileamerindophilist anglophile apostle appreciator apprentice arctophile arbiter archetype architect artisan artist artiste ascendant aspirant asset assignee assigner assistant associate astrophile athlete attendant audiophile author authority autodidact awardee baby backbone backer backup ball fire baron beata beatus beaut beauty beau ideal bees knees begetter belesprit believer belle benchmark benefactor benefactress beneficiary benefit bestower bibliophile big cheese big enchilada big fish big gun big wheel bigwig biophile blessing bodyguard bon vivant boss booster brain brass brother bud buddy buff bundle energy bundle joy builder campaigner captain carer caretaker cartophile catalyst cats meow cause cavalier celebrant celebrator center attention ceo cfo chair chairperson chamberlain champ champion chaperon charmer cherub cherisher chief chieftan child chum cinephile clerisy climber coadjutant coadjutor cognoscente cognoscenti cohort coiner collaborator colleague collector comforter commander companion compeller complement composer comrade concert pianist concierge conductor confederate conferrer confidant confrere connoisseur conservator consoler consul consultant contributor controller convive cooperator corker cornerstone cosmocrat cosmopolitancosmopolite councillor counsel counselor counsellor count coworker crackerjack craftsperson creator credit crew cub curator custodian cynosure dad dancer darling daughter dean dear defender deipnosophist demophile designer devisee devisor devotee digerati dilly director disciple discophile discoverer distributor doer doll donee donor doter rare doater doozy doula doyendoyenne dream dreamboat duke dynamo eager beaver earl ecstatic einstein elder employer enchanter enchantress encourager endorser engineer enkindler enophile ensurer entertainer enthusiast entrepreneur epididact epicure epicurean epitome ergophile escort essence eudaimonist example exec executive exemplar excellency experimenter expert exponent facilitator family fan fancier fascinator fashioner favourite fellow worker fiancé financier fireball fireman first command flame folks foodie foodophile force forebearer forefather foreman forerunner foreseer foundation founder fount fountain fountainhead francophile friend gallophile gastronome gastronomer gastronomist generator gem genius gentleman gentlewoman germanophile gift givee giver godparent godsend gogetter good egg good samaritan good spirit good thing gourmet governor grandee grantee grantor grubstaker guarantor guardian guest guidance counsellor guide guru handler hard worker head head honcho head person heart heartthrob heavy hitter heavyweight height heir heiress heliophile hellenophile help helper helpmate heritor middle english heritress middle english heritrix middle english hero heroine highflier highflier hippophile hit homemaker hopeful host hotshot hot stuff housesitter human humanitarian humdinger husband icon iconophile ideal idol idolizer illuminator improvement inamorata inamorato individual indophile industrialist infant influence influential inheritor initiator innocent innovator inspiration inspirer inspiriter institutor intellect intellectual intelligentsia intimate introducer inventor invitee inviter iranophile jazzophile jewel keeper key kingpin knight knockout ladies man lady lamb latinophile latitudinarian laureate lead leader leading figure leading light legatee legator legend legislator liberal libertarian librocubicularist lieutenant lifeoftheparty lightworker linguaphile little one livewire live one logophile lollapalozza lord lover lulu luminary maestro magician m ...

# %%
len(clean_data_)
# Out:
# 86

# %%
type(clean_data_)
# Out:
# list

# %%
#리스트를 문자열로 변환
data_listToStr = ' '.join(clean_data_)
data_listToStr
# Out:
# '\ufeffacademician acceptor ace aceinthehole achiever adept adherent administrator admirer adorer advantage adviser advisor advocate aelurophile aerophile aesthete aficionadaaficionado aid aide ailurophile alannah alleviator ally almsgiver almsperson alternate altruist agent nounaholic ex workaholic ambassador amoret angel aficionada aficionado affluential americophile amerindophileamerindophilist anglophile apostle appreciator apprentice arctophile arbiter archetype architect artisan artist artiste ascendant aspirant asset assignee assigner assistant associate astrophile athlete attendant audiophile author authority autodidact awardee baby backbone backer backup ball fire baron beata beatus beaut beauty beau ideal bees knees begetter belesprit believer belle benchmark benefactor benefactress beneficiary benefit bestower bibliophile big cheese big enchilada big fish big gun big wheel bigwig biophile blessing bodyguard bon vivant boss booster brain brass brother bud buddy buff bundle energy bundle joy builder campaigner captain carer caretaker cartophile catalyst cats meow cause cavalier celebrant celebrator center attention ceo cfo chair chairperson chamberlain champ champion chaperon charmer cherub cherisher chief chieftan child chum cinephile clerisy climber coadjutant coadjutor cognoscente cognoscenti cohort coiner collaborator colleague collector comforter commander companion compeller complement composer comrade concert pianist concierge conductor confederate conferrer confidant confrere connoisseur conservator consoler consul consultant contributor controller convive cooperator corker cornerstone cosmocrat cosmopolitancosmopolite councillor counsel counselor counsellor count coworker crackerjack craftsperson creator credit crew cub curator custodian cynosure dad dancer darling daughter dean dear defender deipnosophist demophile designer devisee devisor devotee digerati dilly director disciple discophile discoverer distributor doer doll donee donor doter rare doater doozy doula doyendoyenne dream dreamboat duke dynamo eager beaver earl ecstatic einstein elder employer enchanter enchantress encourager endorser engineer enkindler enophile ensurer entertainer enthusiast entrepreneur epididact epicure epicurean epitome ergophile escort essence eudaimonist example exec executive exemplar excellency experimenter expert exponent facilitator family fan fancier fascinator fashioner favourite fellow worker fiancé financier fireball fireman first command flame folks foodie foodophile force forebearer forefather foreman forerunner foreseer foundation founder fount fountain fountainhead francophile friend gallophile gastronome gastronomer gastronomist generator gem genius gentleman gentlewoman germanophile gift givee giver godparent godsend gogetter good egg good samaritan good spirit good thing gourmet governor grandee grantee grantor grubstaker guarantor guardian guest guidance counsellor guide guru handler hard worker head head honcho head person heart heartthrob heavy hitter heavyweight height heir heiress heliophile hellenophile help helper helpmate heritor middle english heritress middle english heritrix middle english hero heroine highflier highflier hippophile hit homemaker hopeful host hotshot hot stuff housesitter human humanitarian humdinger husband icon iconophile ideal idol idolizer illuminator improvement inamorata inamorato individual indophile industrialist infant influence influential inheritor initiator innocent innovator inspiration inspirer inspiriter institutor intellect intellectual intelligentsia intimate introducer inventor invitee inviter iranophile jazzophile jewel keeper key kingpin knight knockout ladies man lady lamb latinophile latitudinarian laureate lead leader leading figure leading light legatee legator legend legislator liberal libertarian librocubicularist lieutenant lifeoftheparty lightworker linguaphile little one livewire live one logophile lollapalozza lord lover lulu luminary maestro magician m ...

# %%
data_str = data_listToStr.split(' ')
data_str[:6]
# Out:
# ['\ufeffacademician', 'acceptor', 'ace', 'aceinthehole', 'achiever', 'adept']

# %%
type(data_str)
# Out:
# list

# %%
len(data_str) #included dupulicated data
# Out:
# 226696

# %%
#중복단어 제거.. remove duplicated words
clean_vocab = list(set(data_str))

# %%
len(clean_vocab)
# Out:
# 1872

# %%
clean_vocab
# Out:
# ['extremist',
#  'neighbour',
#  'jest',
#  'pessimist',
#  'rightwinger',
#  'square',
#  'eligible',
#  'ultimation',
#  'cohort',
#  'upandcomer',
#  'doozy',
#  'psychotic',
#  'donee',
#  'sharp',
#  'role',
#  'round',
#  'dope',
#  'scholarch',
#  'promulgator',
#  'favour',
#  'jackass',
#  'scripter',
#  'something',
#  'xesturgy',
#  'initiative',
#  'favor',
#  'gymnastic',
#  'resolver',
#  'compeller',
#  'pardon',
#  'goof',
#  'engineer',
#  'housesitter',
#  'blabbermouth',
#  'manipulator',
#  'cake',
#  'original',
#  'wise',
#  'motor',
#  'coquette',
#  'nounaholic',
#  'devisee',
#  'earth',
#  'chaperon',
#  'rouse',
#  'demophile',
#  'twit',
#  'professor',
#  'aceinthehole',
#  'working',
#  'madman',
#  'sissy',
#  'provider',
#  'moderate',
#  'success',
#  'troublemaker',
#  'life',
#  'chieftan',
#  'titleholder',
#  'heart',
#  'polymath',
#  'santa',
#  'sittingduck',
#  'saviour',
#  'tattletale',
#  'hostess',
#  'confrere',
#  'count',
#  'pinnacle',
#  'champion',
#  'savant',
#  'dame',
#  'travel',
#  'comfort',
#  'teacher',
#  'elder',
#  'integral',
#  'bliss',
#  'ailurophile',
#  'fascinator',
#  'prophet',
#  'lightweight',
#  'innocent',
#  'excellency',
#  'provoker',
#  'wimp',
#  'inventor',
#  'votary',
#  'adept',
#  'real',
#  'geek',
#  'iranophile',
#  'stabilizer',
#  'sinophile',
#  'queen',
#  'sentinel',
#  'gaiety',
#  'coworker',
#  'energy',
#  'faker',
#  'booster',
#  'wiseguy',
#  'eternal',
#  'realist',
#  'tootsie',
#  'beatus',
#  'strategist',
#  'kiss',
#  'friendly',
#  'staker',
#  'gogetter',
#  'fish',
#  'arbiter',
#  'foreseer',
#  'driver',
#  'selfacceptance',
#  'videophile',
#  'courage',
#  'swell',
#  'consoler',
#  'paradise',
#  'lollapalozza',
#  'premium',
#  'ergophile',
#  'pilot',
#  'researcher',
#  'omnist',
#  'gush',
#  'folks',
#  'sportswoman',
#  'soandso',
#  'philalethist',
#  'soul',
#  'next',
#  'acumen',
#  'nuisance',
#  'enough',
#  'tenor',
#  'ceo',
#  'thief',
#  'prolepsis',
#  'fake',
#  'superwoman',
#  'sucker',
#  'quaff',
#  'scum',
#  'fare',
#  'xenium',
#  'shrimp',
#  'else',
#  'highness',
#  'better',
#  'delight',
#  'tycoon',
#  'squire',
#  'passion',
#  'one',
#  'optimist',
#  'redneck',
#  'temptress',
#  'mentor',
#  'oppositionalist',
#  'enchilada',
#  'compassion',
#  'stipend',
#  'charity',
#  'anglophile',
#  'selfhelp',
#  'student',
#  'bound',
#  'fine',
#  'planner',
#  'urchin',
#  'snuggler',
#  'orchidophile',
#  'maker',
#  'sweetie',
#  'goodhumored',
#  'possible',
#  'whizz',
#  'linguaphile',
#  'superlative',
#  'fashioner',
#  'simplicity',
#  'pathfinder',
#  'teammate',
#  'beaut',
#  'complement',
#  'benchmark',
#  'hard',
#  'fount',
#  'blessing',
#  'genius',
#  'reception',
#  'ripsnorter',
#  'garb',
#  'gambler',
#  'morale',
#  'stereotype',
#  'girly',
#  'growing',
#  'pie',
#  'stipendiary',
#  'degenerate',
#  'thrill',
#  'fanatic',
#  'industrialist',
#  'introducer',
#  'fireball',
#  'freethinking',
#  'help',
#  'vast',
#  'looks',
#  'center',
#  'husband',
#  'worshipper',
#  'cause',
#  'jerk',
#  'mint',
#  'critic',
#  'drifter',
#  'worthy',
#  'producer',
#  'model',
#  'gorgeousness',
#  'means',
#  'stripling',
#  'avowal',
#  'fair',
#  'skeptic',
#  'testament',
#  'trainer',
#  'collaborator',
#  'x',
#  'bridetobe',
#  'philogynist',
#  'companion',
#  'generosity',
#  'indivisible',
#  'reliever',
#  'wellbeing',
#  'gratefulness',
#  'prince',
#  'cheer',
#  'supply',
#  'deipnosophist',
#  'prime',
#  'sexpot',
#  'individual',
#  'tattler',
#  'bore',
#  'dean',
#  'hello',
#  'recluse',
#  'racist',
#  'grubstake',
#  'preceptor',
#  'mortal',
#  'vivant',
#  'cow',
#  'playboy',
#  'raconteur',
#  'demulcent',
#  'monitor',
#  'pleasing',
#  'valiant',
#  'curator',
#  'dainty',
#  'painintheneck',
#  'gentleman',
#  'earlybird',
#  'joker',
#  'busybody',
#  'forgiveness',
#  'officer',
#  'wooer',
#  'kingpin',
#  'make',
#  'slug',
#  'glare',
#  'huntress',
#  'archvillain',
#  'perfectionist',
#  'qualtagh',
#  'minx',
#  'thanksgiving',
#  'youngster',
#  'chief',
#  'gleaming',
#  'commendatory',
#  'victress',
#  'teutonophileteutophile',
#  'belesprit',
#  'true',
#  'highquality',
#  'yift',
#  'cynosure',
#  'improvement',
#  'bastard',
#  'antagonist',
#  'speed',
#  'owner',
#  'amerindophileamerindophilist',
#  'composer',
#  'brute',
#  'notice',
#  'aye',
#  'groove',
#  'ready',
#  'straight',
#  'godsend',
#  'complainer',
#  'teaser',
#  'bum',
#  'quotation',
#  'present',
#  'lassie',
#  'talent',
#  'boaster',
#  'darling',
#  'word',
#  'reason',
#  'employer',
#  'nicety',
#  'right',
#  'clown',
#  'rooter',
#  'luck',
#  'marvel',
#  'slave',
#  'forever',
#  'partypooper',
#  'weakling',
#  'social',
#  'twotimer',
#  'heiress',
#  'transient',
#  'policy',
#  'fleet',
#  'contemporary',
#  'maven',
#  'support',
#  'procto',
#  'alcoholic',
#  'promotion',
#  'duke',
#  'sociable',
#  'sculptor',
#  'comrade',
#  'philonoist',
#  'celibate',
#  'might',
#  'schatzi',
#  'sportsmanship',
#  'renovation',
#  'philanthropy',
#  'friend',
#  'visionary',
#  'uplifting',
#  'great',
#  'tuition',
#  'counsel',
#  'babe',
#  'distributor',
#  'harmony',
#  'reacher',
#  'widow',
#  'shelter',
#  'jazzophile',
#  'creep',
#  'legislator',
#  'testimonial',
#  'winner',
#  'training',
#  'number',
#  'siren',
#  'cat',
#  'fulfilling',
#  'person',
#  'stinker',
#  'pinup',
#  'chairperson',
#  'heartbreaker',
#  'gather',
#  'bibliophile',
#  'golconda',
#  'classic',
#  'scatterbrain',
#  'nurse',
#  'dilly',
#  'nod',
#  'premier',
#  'sire',
#  'golddigger',
#  'apprentice',
#  'sovereign',
#  'nirvana',
#  'butterfingers',
#  'diplomat',
#  'fountain',
#  'loafer',
#  'ensurer',
#  'cosmocrat',
#  'pigsney',
#  'whiz',
#  'conservative',
#  'care',
#  'hot',
#  'zest',
#  'grump',
#  'god',
#  'drunk',
#  'uberty',
#  'nonpareil',
#  'wisdom',
#  'aide',
#  'neurotic',
#  'sensibility',
#  'yield',
#  'credit',
#  'luxury',
#  'super',
#  'broker',
#  'sugar',
#  'epicurean',
#  'faithful',
#  'cover',
#  'leader',
#  'kid',
#  'testator',
#  'spiritual',
#  'escort',
#  'witch',
#  'eccentric',
#  'founder',
#  'glamour',
#  'qui',
#  'user',
#  'grandmaster',
#  'lefty',
#  'fry',
#  'administrator',
#  'prevailer',
#  'coequal',
#  'confederate',
#  'granny',
#  'runner',
#  'powerhouse',
#  'younker',
#  'minikin',
#  'smile',
#  'pragmatic',
#  'timesaver',
#  'professional',
#  'sleek',
#  'klutz',
#  'notable',
#  'stunner',
#  'wreck',
#  'admirer',
#  'gist',
#  'metropolitan',
#  'rare',
#  'associate',
#  'enchanter',
#  'striver',
#  'sense',
#  'materialist',
#  'shine',
#  'blossoming',
#  'cavalier',
#  'jester',
#  'constant',
#  'glister',
#  'splendor',
#  'wheelerdealer',
#  'equal',
#  'plenitude',
#  'character',
#  'sensation',
#  'rejoicer',
#  'righthand',
#  'personality',
#  'paradigm',
#  'affluential',
#  'nurturer',
#  'superstar',
#  'hit',
#  'musicophile',
#  'weasel',
#  'heavy',
#  'faith',
#  'amoret',
#  'cheater',
#  'problemsolver',
#  'standard',
#  'garland',
#  'gentlefolk',
#  'brain',
#  'concierge',
#  'astrophile',
#  'choice',
#  'endorser',
#  'clairvoyant',
#  'weapon',
#  'virtue',
#  'total',
#  'smarty',
#  'mommy',
#  'sexobject',
#  'beaver',
#  'glisten',
#  'virgin',
#  'hippophile',
#  'paragon',
#  'awardee',
#  'youth',
#  'typhlophile',
#  'captain',
#  'hopeful',
#  'heritrix',
#  'heaven',
#  'philomath',
#  'fun',
#  'bees',
#  'plug',
#  'salient',
#  'betterment',
#  'magician',
#  'bigot',
#  'counsellor',
#  'whip',
#  'purist',
#  'organizer',
#  'stickinthemud',
#  'goodhearted',
#  'advisor',
#  'bundle',
#  'merrymaker',
#  'prospective',
#  'turkey',
#  'clear',
#  'zaniness',
#  'nursling',
#  'fool',
#  'foresight',
#  'enemy',
#  'gloss',
#  'blueribbon',
#  'show',
#  'vip',
#  'turophile',
#  'coadjutant',
#  'overseer',
#  'quality',
#  'beauty',
#  'coward',
#  'trash',
#  'oenophile',
#  'progressive',
#  'rich',
#  'gem',
#  'force',
#  'prayer',
#  'craftsperson',
#  'interest',
#  'presenter',
#  'indophile',
#  'packrat',
#  'lust',
#  'collector',
#  'eager',
#  'nimblewit',
#  'lawbreaker',
#  'gladhand',
#  'spark',
#  'buffoon',
#  'doater',
#  'biophile',
#  'intellectual',
#  'laureate',
#  'boost',
#  'neighbor',
#  'seeker',
#  'tightwad',
#  'thalassophile',
#  'reward',
#  'honey',
#  'scholarship',
#  'defender',
#  'shooter',
#  'lustre',
#  'thank',
#  'matron',
#  'particular',
#  'decency',
#  'numero',
#  'discophile',
#  'wire',
#  'laugh',
#  'alannah',
#  'quickthinker',
#  'sophisticate',
#  'psychopath',
#  'special',
#  'addition',
#  'ascendant',
#  'alternate',
#  'cfo',
#  'mate',
#  'moneygrubber',
#  'uno',
#  'transcendent',
#  'individualist',
#  'storyteller',
#  'ladykiller',
#  'married',
#  'sexmaniac',
#  'solver',
#  'bonus',
#  'pretty',
#  'superman',
#  'understanding',
#  'supporter',
#  'prima',
#  'entertainer',
#  'recuperation',
#  'stalwart',
#  'catalyst',
#  'pacifier',
#  'swain',
#  'spinster',
#  'author',
#  'daring',
#  'learning',
#  'helper',
#  'guardian',
#  'slowpoke',
#  'councillor',
#  'virtuosity',
#  'host',
#  'aunt',
#  'salute',
#  'big',
#  'fortunate',
#  'principal',
#  'inamorata',
#  'paladin',
#  'glance',
#  'aficionadaaficionado',
#  'claus',
#  'freak',
#  'failure',
#  'power',
#  'vamp',
#  'dream',
#  'backseatdriver',
#  'salt',
#  'rejoicing',
#  'grandee',
#  'dynamo',
#  'honcho',
#  'rainmaker',
#  'luster',
#  'connoisseur',
#  'exponent',
#  'hoodlum',
#  'bonehead',
#  'mitigator',
#  'representative',
#  'beata',
#  'bornfighter',
#  'artist',
#  'tiptop',
#  'matchmaker',
#  'jubilation',
#  'ex',
#  'plan',
#  'baron',
#  'pest',
#  'gumption',
#  'plum',
#  'quaintisiness',
#  'clerisy',
#  'motivator',
#  'inspiration',
#  'significance',
#  'manner',
#  'serene',
#  'intelligentsia',
#  'boss',
#  'tutelary',
#  'paranoid',
#  'nymph',
#  'jewel',
#  'playmate',
#  'egghead',
#  'authority',
#  'ornithophile',
#  'novel',
#  'autodidact',
#  'wheeler',
#  'sympathizer',
#  'director',
#  'addict',
#  'longhair',
#  'animal',
#  'tranquillity',
#  'good',
#  'triumph',
#  'goodwill',
#  'crew',
#  'chuckle',
#  'sprout',
#  'progenitor',
#  'comforter',
#  'peach',
#  'trustee',
#  'cynic',
#  'benefit',
#  'consul',
#  'progress',
#  'victim',
#  'dunce',
#  'close',
#  'mademoiselle',
#  'gallantry',
#  'deserving',
#  'catch',
#  'national',
#  'practicaljoker',
#  'veracity',
#  'hick',
#  'fountainhead',
#  'lover',
#  'teenager',
#  'pistol',
#  'spot',
#  'liking',
#  'sexist',
#  'celebrant',
#  'ooze',
#  'apostle',
#  'hero',
#  'favourite',
#  'nag',
#  'definite',
#  'glitz',
#  'parent',
#  'blockhead',
#  'bon',
#  'maestro',
#  'whizbang',
#  'small',
#  'cheers',
#  'invite',
#  'communicator',
#  'materfamilias',
#  'object',
#  'pard',
#  'savage',
#  'moving',
#  'sprite',
#  'drawer',
#  'inspirer',
#  'adventurer',
#  'climber',
#  'note',
#  'dependable',
#  'queenhood',
#  'dummy',
#  'tact',
#  'daughter',
#  'rational',
#  'bonanza',
#  'rise',
#  'xenophile',
#  'generator',
#  'traditionalist',
#  'honesty',
#  'aelurophile',
#  'old',
#  'gratification',
#  'grammy',
#  'man',
#  'worldtraveler',
#  'actor',
#  'builder',
#  'goodygoody',
#  'serenity',
#  'controller',
#  'modern',
#  'princess',
#  'savory',
#  'skill',
#  'lady',
#  'gangster',
#  'headman',
#  'livewire',
#  'pal',
#  'sensationalist',
#  'beginner',
#  'legend',
#  'moron',
#  'warden',
#  'ecstatic',
#  'junkie',
#  'glimmer',
#  'zeal',
#  'backer',
#  'kind',
#  'fire',
#  'reputation',
#  'tease',
#  'brother',
#  'earl',
#  'gut',
#  'glint',
#  'pacifist',
#  'glitterati',
#  'progeny',
#  'gag',
#  'natural',
#  'servant',
#  'altruist',
#  'paterfamilias',
#  'memorymaker',
#  'funny',
#  'optimum',
#  'believer',
#  'radiant',
#  'opportunity',
#  'english',
#  'run',
#  'peer',
#  'top',
#  'set',
#  'growth',
#  'inheritor',
#  'theodidact',
#  'coiner',
#  'punk',
#  'lionheart',
#  'fancy',
#  'teenybopper',
#  'fiancé',
#  'heritress',
#  'gossip',
#  'majordomo',
#  'moocher',
#  'contributor',
#  'ms',
#  'rhapsody',
#  'meow',
#  'aid',
#  'sufficiency',
#  'steady',
#  'human',
#  'garden',
#  'vogue',
#  'trailblazer',
#  'willpower',
#  'gratitude',
#  'science',
#  'copycat',
#  'loony',
#  'asset',
#  'rejuvenation',
#  'people',
#  'stir',
#  'vegetarian',
#  'postulant',
#  'reverence',
#  'menace',
#  'cats',
#  'dingbat',
#  'aficionado',
#  'utmost',
#  'wheel',
#  'chum',
#  'rose',
#  'grit',
#  'facilitator',
#  'gale',
#  'illuminator',
#  'savvy',
#  'lieutenant',
#  'goodnatured',
#  'quirk',
#  'dumbbell',
#  'wife',
#  'initiator',
#  'quitter',
#  'consciousness',
#  'coordinator',
#  'play',
#  'method',
#  'gentlewoman',
#  'executive',
#  'libertarian',
#  'invalid',
#  'conductor',
#  'accuracy',
#  'vaulter',
#  'buff',
#  'boob',
#  'nabit',
#  'selfdiscipline',
#  'socializer',
#  'snot',
#  'praise',
#  'credential',
#  'gala',
#  'neonate',
#  'felicity',
#  'traitor',
#  'governor',
#  'influential',
#  'protagonist',
#  'happening',
#  'child',
#  'sex',
#  'positive',
#  'fan',
#  'tough',
#  'stylist',
#  'experimenter',
#  'squaw',
#  'natation',
#  'kept',
#  'bimbo',
#  'ethic',
#  'lasting',
#  'celebrator',
#  'rapture',
#  'culprit',
#  'drama',
#  'essence',
#  'enlivening',
#  'monster',
#  'infinite',
#  'solon',
#  'forward',
#  'wonderment',
#  'doula',
#  'touch',
#  'sublime',
#  'loser',
#  'galahad',
#  'matriarch',
#  'forefather',
#  'phenomenon',
#  'today',
#  'sympathy',
#  'hitter',
#  'skirt',
#  'yoke',
#  'chortle',
#  'einstein',
#  'leading',
#  'creator',
#  'knight',
#  'president',
#  'idol',
#  'softy',
#  'flirt',
#  'warantor',
#  'tune',
#  'well',
#  'leftwinger',
#  'pep',
#  'serendipity',
#  'mediator',
#  'figure',
#  'nipper',
#  'ham',
#  'foreman',
#  'forebearer',
#  'therapist',
#  'patron',
#  'fortune',
#  'moppet',
#  'deep',
#  'lunatic',
#  'crowdpleaser',
#  'underwriter',
#  'trueblue',
#  'influence',
#  'spectacular',
#  'backbone',
#  'shape',
#  'hope',
#  'precious',
#  'publisher',
#  'protégé',
#  'settling',
#  'conformist',
#  'ecstasy',
#  'standout',
#  'quintessence',
#  ...]

# %%
personal_nouns_vacab = ",".join(clean_vocab)
type(personal_nouns_vacab)
# Out:
# str

# %%
#파일을 personalNouns.txt 로 저장한다.  
saveFile = open('data/preprocessed_personalNouns.txt', 'w')
saveFile.write(personal_nouns_vacab)
saveFile.close()

# %%
#테스르를 위해서 다음과 같은 단어를 넣어보자 . 'during', 'in the', 'since', 'at', 'until', 'ago', 'yet', 'after', 'past', 'long', 'just'
